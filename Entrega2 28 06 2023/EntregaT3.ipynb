# %%
import pandas as pd
df = pd.read_csv('./afa_2015_2022_spa.csv')
df.head()
# informacion rapida del dataset aplicando Head
# print("Información del dataset:")
# df.head()

# Mostrar las primeras filas del dataset
# print("Primeras filas del dataset:")
# print(df.head())

# número de filas y columnas del dataset
# num_filas, num_columnas = df.shape
# print("Número de filas:", num_filas)
# print("Número de columnas:", num_columnas)

# Obtener el nombre de las columnas
# print("Nombres de las columnas:")
#df.columns

# Obtener el número total de registros
# num_registros = len(df)
# print("Número total de registros:", num_registros)

# Obtener un resumen estadístico de las columnas numéricas
# print("Resumen estadístico:")
# print(df.describe())

# Obtener la cantidad de valores únicos en cada columna
# print("Valores únicos por columna:")
# print(df.nunique())

# Obtener la cantidad de registros no nulos en cada columna
# print("Registros no nulos por columna:")
# print(df.count())
# Out:
#             torneo  fecha  partido   equipo_local equipo_visitante  \
# 0  Campeonato 2015      1        1          Velez         Aldosivi
# 1  Campeonato 2015      1        2    Racing Club  Rosario Central
# 2  Campeonato 2015      1        3    San Lorenzo            Colon
# 3  Campeonato 2015      1        4  Gimnasia (LP)   Def y Justicia
# 4  Campeonato 2015      1        5     Godoy Cruz  San Martin (SJ)
#
#    goles_local  goles_visitante  posesion_local  tiros_arco_local  \
# 0            2                0             NaN               NaN
# 1            0                1             NaN               NaN
# 2            2                0             NaN               NaN
# 3            0                1             NaN               NaN
# 4            1                1             NaN               NaN
#
#    intentos_local  ...  proporcion_zurdos_local  valor_mercado_visitante  \
# 0             NaN  ...                 0.301887                    8.725
# ...

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
data = [1, 1, 2, 3, 3, 3, 4, 4, 5]

plt.hist(data)
plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.title('Histograma')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(df['tiros_arco_local'], df['goles_local'])
plt.title('Relación entre tiros al arco y goles del equipo local')
plt.xlabel('Tiros al arco del equipo local')
plt.ylabel('Goles del equipo local')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='altura_media_visitante')
plt.title('Distribución de la altura media de los jugadores del equipo visitante')
plt.xlabel('Altura media')
plt.ylabel('Frecuencia')
plt.show()
